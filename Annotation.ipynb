# %%
import requests

file_url = "https://upload.wikimedia.org/wikipedia/commons/2/24/Common_kestrel_falco_tinnunculus.jpg"
output_filename = "image.jpg"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

response = requests.get(file_url, stream=True, headers=headers)
response.raise_for_status() # Raise an HTTPError for bad responses (4xx or 5xx)

with open(output_filename, 'wb') as out_file:
    for chunk in response.iter_content(chunk_size=8192):
        out_file.write(chunk)

print(f"File downloaded and saved as {output_filename}")
# Out:
# File downloaded and saved as image.jpg

# %%
import urllib.request

url = 'https://box.fu-berlin.de/s/P4LZ6JYBnbqdewf/download/age_pt.zip'
urllib.request.urlretrieve(url, "data.zip")
# Out:
# ('data.zip', <http.client.HTTPMessage at 0x7c963f7df530>)

# %%
# !mkdir data

# %%
from zipfile import ZipFile
ZipFile("data.zip").extractall("./data")
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# /tmp/ipython-input-3218814548.py in <cell line: 0>()
#       1 from zipfile import ZipFile
# ----> 2 ZipFile("data.zip").extractall("./data")
#
# /usr/lib/python3.12/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1368         try:
#    1369             if mode == 'r':
# -> 1370                 self._RealGetContents()
#    1371             elif mode in ('w', 'x'):
#    1372                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.12/zipfile/__init__.py in _RealGetContents(self)
#    1435             raise BadZipFile("File is not a zip file")
#    1436         if not endrec:
# -> 1437             raise BadZipFile("File is not a zip file")
#    1438         if self.debug > 1:
#    1439             print(endrec)
# ...

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
pip install jupyter_bbox_widget
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 24.0 MB/s eta 0:00:00
# ...

# %%
from jupyter_bbox_widget import BBoxWidget
widget = BBoxWidget(
    image="image.jpg",
    classes=['apple', 'orange', 'pear'],
)
widget

# %%
widget.bboxes
# Out:
# [{'x': 1139, 'y': 1650, 'width': 0, 'height': 0, 'label': 'apple'},
#  {'x': 390, 'y': 447, 'width': 0, 'height': 0, 'label': 'orange'},
#  {'x': 373, 'y': 400, 'width': 0, 'height': 0, 'label': 'orange'},
#  {'x': 361, 'y': 339, 'width': 0, 'height': 0, 'label': 'orange'},
#  {'x': 398, 'y': 290, 'width': 0, 'height': 0, 'label': 'orange'},
#  {'x': 482, 'y': 259, 'width': 0, 'height': 0, 'label': 'orange'},
#  {'x': 548, 'y': 278, 'width': 0, 'height': 0, 'label': 'orange'},
#  {'x': 602, 'y': 314, 'width': 0, 'height': 0, 'label': 'orange'},
#  {'x': 645, 'y': 387, 'width': 0, 'height': 0, 'label': 'orange'},
#  {'x': 688, 'y': 429, 'width': 0, 'height': 0, 'label': 'orange'},
#  {'x': 728, 'y': 475, 'width': 0, 'height': 0, 'label': 'orange'},
#  {'x': 781, 'y': 539, 'width': 0, 'height': 0, 'label': 'orange'},
#  {'x': 801, 'y': 638, 'width': 0, 'height': 0, 'label': 'orange'},
#  {'x': 822, 'y': 722, 'width': 0, 'height': 0, 'label': 'orange'},
# ...

# %%
import os
flist = os.listdir('data/age_pt/train/2')

# %%
flist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 flist
#
# NameError: name 'flist' is not defined

# %%
import pandas as pd
d = pd.DataFrame()

# %%
from jupyter_bbox_widget import BBoxWidget

n = 2

widget = BBoxWidget(
    image = "data/age_pt/train/2/" + flist[n],
    classes=['Eltern','Kücken'],
)
widget

# %%
def save_bboxes(widget, n, d):

  import pandas as pd
  #d = pd.DataFrame()
  for el in widget.bboxes:
    df_ = pd.DataFrame({"file_name": [flist[n]],
                      "x": [el['x']],
                      "y": [el['y']],
                      "w": [el['width']],
                      "h": [el['height']],
                      "l": [el['label']]})
    d = pd.concat([d, df_]).reset_index(drop = True)

  return d

# %%
d = save_bboxes(widget, n, d)

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
d.to_csv('bboxes.csv')
